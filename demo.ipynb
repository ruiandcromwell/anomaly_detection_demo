# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 22,15
import matplotlib
matplotlib.style.use('fivethirtyeight')

e1 = 'temperature_vancouver'
e2 = 'daily_temperatures'
e3 = 'test_ts'
e4 = 'air_passengers'  # nice seasonal ts with a upward trend
e5 = 'retail_sales'  # there is a change in baseline, good for testing adaptation
e6 = 'qps'
e7 = 'artificialWithAnomaly/art_daily_jumpsup'
e8 = 'artificialNoAnomaly/art_daily_small_noise'

# %%
import cli
from config import Config

config = Config(
    debug_mode=False,
    additive_hw_confidence_band_factor=20.0,
)
result = cli.demo_anomaly(e6, config)
# cli.plot_anomaly(result, begin_ts='2019-06-26 07:00:00', end_ts='2019-07-01 11:00:00')
# Out:
# No handles with labels found to put in legend.
# /Users/wangrui/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# /Users/wangrui/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
cli.plot_anomaly(result)
# Out:
# No handles with labels found to put in legend.
